# %%
# Installing required package to be able to work with excel files.
# If packages are installed then you will need to restart the the kernel before continuing.

pip install openpyxl
# Out:
#   Cell In[4], line 4
#     pip install openpyxl
#         ^
# SyntaxError: invalid syntax

# %%
# importing required packages into notebook
import pandas as pd
import requests
import os
import io
import zipfile

# %% [markdown]
# # Real-world Data Wrangling

# %% [markdown]
# In this project, you will apply the skills you acquired in the course to gather and wrangle real-world data with two datasets of your choice.
#
# You will retrieve and extract the data, assess the data programmatically and visually, accross elements of data quality and structure, and implement a cleaning strategy for the data. You will then store the updated data into your selected database/data store, combine the data, and answer a research question with the datasets.
#
# Throughout the process, you are expected to:
#
# 1. Explain your decisions towards methods used for gathering, assessing, cleaning, storing, and answering the research question
# 2. Write code comments so your code is more readable

# %% [markdown]
# ## 1. Gather data
#
# In this section, you will extract data using two different data gathering methods and combine the data. Use at least two different types of data-gathering methods.

# %% [markdown]
# ### **1.1.** Problem Statement
# In 2-4 sentences, explain the kind of problem you want to look at and the datasets you will be wrangling for this project.

# %% [markdown]
# >I have decided to investigate if any correlation exists between unempoloyment rate and GDP (Gross Domestic Product) at the county level within the United States. The unemployment data will be sourced from The United States Department of Agriculture's website. The GDP data will be sourced from the U.S. Department of Commerce's Bureau of Economic Analysis website.

# %% [markdown]
# Finding the right datasets can be time-consuming. Here we provide you with a list of websites to start with. But we encourage you to explore more websites and find the data that interests you.
#
# * Google Dataset Search https://datasetsearch.research.google.com/
# * The U.S. Government’s open data https://data.gov/
# * UCI Machine Learning Repository https://archive.ics.uci.edu/ml/index.php

# %% [markdown]
# ### **1.2.** Gather at least two datasets using two different data gathering methods
#
# List of data gathering methods:
#
# - Download data manually
# - Programmatically downloading files
# - Gather data by accessing APIs
# - Gather and extract data from HTML files using BeautifulSoup
# - Extract data from a SQL database
#
# Each dataset must have at least two variables, and have greater than 500 data samples within each dataset.
#
# For each dataset, briefly describe why you picked the dataset and the gathering method (2-3 full sentences), including the names and significance of the variables in the dataset. Show your work (e.g., if using an API to download the data, please include a snippet of your code).
#
# Load the dataset programmtically into this notebook.

# %% [markdown]
# #### **Dataset 1**
#
# >I chose this dataset because it includes the unemployement data I am looking for from an official source of the data. The data is also formatted in a way that will make it much easier later when it comes time to combine with my other dataset.
#
# Type: *XLSX File (Microsoft Excel)*
#
# Method: *The data set was downloaded manually from https://www.ers.usda.gov/data-products/county-level-data-sets/county-level-data-sets-download-data/
#
# #### Dataset Variables
#
#     FIPS_Code: State+county Federal Information Processing Standard code
#     State: State abbreviation
#     Area_Name: State or county name
#     Rural_Urban_Continuum_Code_2013: Rural-urban Continuum Code, 2013
#     Urban_Influence_Code_2013: Urban Influence Code, 2013
#     Metro_2013: Metro nonmetro dummy 0=Nonmetro 1=Metro
#     Civilian_labor_force_2000: Civilian labor force annual average, 2000
#     Employed_2000: Number employed annual average, 2000
#     Unemployed_2000: Number unemployed annual average, 2000
#     Unemployment_rate_2000: Unemployment rate, 2000
#     Civilian_labor_force_2001: Civilian labor force annual average, 2001
#     Employed_2001: Number employed annual average, 2001
#     Unemployed_2001: Number unemployed annual average, 2001
#     Unemployment_rate_2001: Unemployment rate, 2001
#     Civilian_labor_force_2002: Civilian labor force annual average, 2002
#     Employed_2002: Number employed annual average, 2002
#     Unemployed_2002: Number unemployed annual average, 2002
#     Unemployment_rate_2002: Unemployment rate, 2002
#     Civilian_labor_force_2003: Civilian labor force annual average, 2003
#     Employed_2003: Number employed annual average, 2003
#     Unemployed_2003: Number unemployed annual average, 2003
#     Unemployment_rate_2003: Unemployment rate, 2003
#     Civilian_labor_force_2004: Civilian labor force annual average, 2004
#     Employed_2004: Number employed annual average, 2004
#     Unemployed_2004: Number unemployed annual average, 2004
#     Unemployment_rate_2004: Unemployment rate, 2004
#     Civilian_labor_force_2005: Civilian labor force annual average, 2005
#     Employed_2005: Number employed annual average, 2005
#     Unemployed_2005: Number unemployed annual average, 2005
#     Unemployment_rate_2005:	Unemployment rate, 2005
#     Civilian_labor_force_2006: Civilian labor force annual average, 2006
#     Employed_2006: Number employed annual average, 2006
#     Unemployed_2006: Number unemployed annual average, 2006
#     Unemployment_rate_2006: Unemployment rate, 2006
#     Civilian_labor_force_2007: Civilian labor force annual average, 2007
#     Employed_2007: Number employed annual average, 2007
#     Unemployed_2007: Number unemployed annual average, 2007
#     Unemployment_rate_2007: Unemployment rate, 2007
#     Civilian_labor_force_2008: Civilian labor force annual average, 2008
#     Employed_2008: Number employed annual average, 2008
#     Unemployed_2008: Number unemployed annual average, 2008
#     Unemployment_rate_2008: Unemployment rate, 2008
#     Civilian_labor_force_2009: Civilian labor force annual average, 2009
#     Employed_2009: Number employed annual average, 2009
#     Unemployed_2009: Number unemployed annual average, 2009
#     Unemployment_rate_2009: Unemployment rate, 2009
#     Civilian_labor_force_2010: Civilian labor force annual average, 2010
#     Employed_2010: Number employed annual average, 2010
#     Unemployed_2010: Number unemployed annual average, 2010
#     Unemployment_rate_2010:	Unemployment rate, 2010
#     Civilian_labor_force_2011: Civilian labor force annual average, 2011
#     Employed_2011: Number employed annual average, 2011
#     Unemployed_2011: Number unemployed annual average, 2011
#     Unemployment_rate_2011: Unemployment rate, 2011
#     Civilian_labor_force_2012: Civilian labor force annual average, 2012
#     Employed_2012: Number employed annual average, 2012
#     Unemployed_2012: Number unemployed annual average, 2012
#     Unemployment_rate_2012: Unemployment rate, 2012
#     Civilian_labor_force_2013: Civilian labor force annual average, 2013
#     Employed_2013: Number employed annual average, 2013
#     Unemployed_2013: Number unemployed annual average, 2013
#     Unemployment_rate_2013: Unemployment rate, 2013
#     Civilian_labor_force_2014: Civilian labor force annual average, 2014
#     Employed_2014: Number employed annual average, 2014
#     Unemployed_2014: Number unemployed annual average, 2014
#     Unemployment_rate_2014: Unemployment rate, 2014
#     Civilian_labor_force_2015: Civilian labor force annual average, 2015
#     Employed_2015: Number employed annual average, 2015
#     Unemployed_2015: Number unemployed annual average, 2015
#     Unemployment_rate_2015: Unemployment rate, 2015
#     Civilian_labor_force_2016: Civilian labor force annual average, 2016
#     Employed_2016: Number employed annual average, 2016
#     Unemployed_2016: Number unemployed annual average, 2016
#     Unemployment_rate_2016: Unemployment rate, 2016
#     Civilian_labor_force_2017: Civilian labor force annual average, 2017
#     Employed_2017: Number employed annual average, 2017
#     Unemployed_2017: Number unemployed annual average, 2017
#     Unemployment_rate_2017: Unemployment rate, 2017
#     Civilian_labor_force_2018: Civilian labor force annual average, 2018
#     Employed_2018: Number employed annual average, 2018
#     Unemployed_2018: Number unemployed annual average, 2018
#     Unemployment_rate_2018: Unemployment rate, 2018
#     Civilian_labor_force_2019: Civilian labor force annual average, 2019
#     Employed_2019: Number employed annual average, 2019
#     Unemployed_2019: Number unemployed annual average, 2019
#     Unemployment_rate_2019: Unemployment rate, 2019
#     Civilian_labor_force_2020: Civilian labor force annual average, 2020
#     Employed_2020: Number employed annual average, 2020
#     Unemployed_2020: Number unemployed annual average, 2020
#     Unemployment_rate_2020:	Unemployment rate, 2020
#     Civilian_labor_force_2021: Civilian labor force annual average, 2021
#     Employed_2021: Number employed annual average, 2021
#     Unemployed_2021: Number unemployed annual average, 2021
#     Unemployment_rate_2021: Unemployment rate, 2021
#     Civilian_labor_force_2022: Civilian labor force annual average, 2022
#     Employed_2022: Number employed annual average, 2022
#     Unemployed_2022: Number unemployed annual average, 2022
#     Unemployment_rate_2022: Unemployment rate, 2022
#     Median_Household_Income_2021: Estimate of median household income, 2021
#     Med_HH_Income_Percent_of_State_Total_2021:County household median income

# %%
# reading the excel file into a dataframe and looking at the shape data and using the head method to inspect some of the data.
file = 'Unemployment.xlsx'
df_ue = pd.read_excel(file, sheet_name = 0, skiprows=4)
print(df_ue.shape[0],'rows of data')
df_ue.head()
# Out:
# 3277 rows of data
#    FIPS_Code State           Area_Name  Rural_Urban_Continuum_Code_2013  \
# 0          0    US       United States                              NaN
# 1       1000    AL             Alabama                              NaN
# 2       1001    AL  Autauga County, AL                              2.0
# 3       1003    AL  Baldwin County, AL                              3.0
# 4       1005    AL  Barbour County, AL                              6.0
#
#    Urban_Influence_Code_2013  Metro_2013  Civilian_labor_force_2000  \
# 0                        NaN         NaN                142601576.0
# 1                        NaN         NaN                  2147173.0
# 2                        2.0         1.0                    21861.0
# 3                        2.0         1.0                    69979.0
# 4                        6.0         0.0                    11449.0
#
#    Employed_2000  Unemployed_2000  Unemployment_rate_2000  ...  \
# ...

# %% [markdown]
# #### Dataset 2
#
# >I chose this dataset because it includes the GDP data I am looking for from an official source for the data. The data is also formatted very similarly to my other dataset which will make it easier when it comes time to combine both of my data sets.
#
# Type: *CSV file contained within a zip file*
#
# Method: *The files were programatically downloaded from BEA.gov*
#
# #### Dataset variables:
#
#     GeoFIPS: State+county Federal Information Processing Standard code
#     GeoName: State or county name
#     Region: Geographic Region code
#     TableName: Name of the original table data was located in
#     LineCode: Coding data to identify what kind of GDP data the row consists of
#     IndustryClassification: Industry Coding for breakdown data
#     Description: Description to identify what kind of GDP data the row consists
#     Unit: What kind of measure of change for the rows of data
#     2018: Percent GDP Change Data for 2018
#     2019: Percent GDP Change Data for 2019
#     2020: Percent GDP Change Data for 2020
#     2021: Percent GDP Change Data for 2021
#     2022: Percent GDP Change Data for 2022

# %%
#URL where data is located
url = 'https://apps.bea.gov/regional/zip/CAGDP11.zip'

# Making a directory to dowload my zip file if it doesn't already exist.
folder_name = 'GDP'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)
    
# Downloading the required zip file from the url and extracting the correct csv into the folder path.
r = requests.get(url)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extract('CAGDP11__ALL_AREAS_2018_2022.csv', path="GDP/")
    
# Creating a dataframe from the extracted CSV.
file = 'GDP/CAGDP11__ALL_AREAS_2018_2022.csv'
df_gdp = pd.read_csv(file, encoding='latin-1')

print(df_gdp.shape[0],'rows of data')
df_gdp.head()
# Out:
# 108056 rows of data
# /tmp/ipykernel_56/941335752.py:16: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_gdp = pd.read_csv(file, encoding='latin-1')
#     GeoFIPS          GeoName Region TableName  LineCode  \
# 0   "00000"  United States *          CAGDP11       1.0
# 1   "00000"  United States *          CAGDP11       2.0
# 2   "00000"  United States *          CAGDP11       3.0
# 3   "00000"  United States *          CAGDP11       6.0
# 4   "00000"  United States *          CAGDP11      10.0
#
#   IndustryClassification                                       Description  \
# 0                    ...              All industry total (percent change)
# 1                    ...                               Private industries
# 2                     11       Agriculture, forestry, fishing and hunting
# 3                     21    Mining, quarrying, and oil and gas extraction
# ...

# %% [markdown]
# Optional data storing step: You may save your raw dataset files to the local data store before moving to the next step.

# %%
#Optional: store the raw data in your local data store

# %% [markdown]
# ## 2. Assess data
#
# Assess the data according to data quality and tidiness metrics using the report below.
#
# List **two** data quality issues and **two** tidiness issues. Assess each data issue visually **and** programmatically, then briefly describe the issue you find.  **Make sure you include justifications for the methods you use for the assessment.**

# %% [markdown]
# ### Quality Issue 1:

# %%
#visually inspecting a sample of the df_gdp dataframe
df_gdp.sample(5)
# Out:
#          GeoFIPS       GeoName Region TableName  LineCode  \
# 107742   "56043"  Washakie, WY    7.0   CAGDP11      89.0
# 11879    "12029"     Dixie, FL      5   CAGDP11      50.0
# 41893    "24029"      Kent, MD      2   CAGDP11      11.0
# 64835    "36081"    Queens, NY      2   CAGDP11      90.0
# 33970    "20179"  Sheridan, KS      4   CAGDP11      10.0
#
#        IndustryClassification  \
# 107742               22,48-49
# 11879                   52,53
# 41893                      23
# 64835                31-33,51
# 33970                      22
#
#                                               Description               Unit  \
# 107742                      Transportation and utilities   Percentage points
# 11879     Finance, insurance, real estate, rental, and...  Percentage points
# 41893                                       Construction   Percentage points
# 64835                      Manufacturing and information   Percentage points
# ...

# %%
# Visually inspecting a sample of the df_gdp data frame.
df_ue.sample(5)
# Out:
#       FIPS_Code State            Area_Name  Rural_Urban_Continuum_Code_2013  \
# 1418      27151    MN     Swift County, MN                              7.0
# 243        6093    CA  Siskiyou County, CA                              6.0
# 613       17000    IL             Illinois                              NaN
# 2028      37199    NC    Yancey County, NC                              8.0
# 1449      28037    MS  Franklin County, MS                              9.0
#
#       Urban_Influence_Code_2013  Metro_2013  Civilian_labor_force_2000  \
# 1418                        9.0         0.0                     5654.0
# 243                         6.0         0.0                    19128.0
# 613                         NaN         NaN                  6494429.0
# 2028                        7.0         0.0                     8516.0
# 1449                       10.0         0.0                     3434.0
#
#       Employed_2000  Unemployed_2000  Unemployment_rate_2000  ...  \
# ...

# %%
# Inspecting how many matching unique location names there are between both data sets

# Creating lists of unique location names from both data frames.
gdp_ls = df_gdp['GeoName'].unique()
ue_ls = df_ue['Area_Name'].unique()

# Comparing both lists for matches.
count = 0
for place in gdp_ls:
    if place in ue_ls:
        count += 1
        print(place)
print('There are',count,'matching unique location names between both data sets.')
# Out:
# Alabama
# Alaska
# Aleutians East Borough, AK
# Aleutians West Census Area, AK
# Bethel Census Area, AK
# Bristol Bay Borough, AK
# Denali Borough, AK
# Dillingham Census Area, AK
# Fairbanks North Star Borough, AK
# Haines Borough, AK
# Kenai Peninsula Borough, AK
# Kodiak Island Borough, AK
# Lake and Peninsula Borough, AK
# Matanuska-Susitna Borough, AK
# Nome Census Area, AK
# North Slope Borough, AK
# Northwest Arctic Borough, AK
# Southeast Fairbanks Census Area, AK
# Yukon-Koyukuk Census Area, AK
# Arizona
# Arkansas
# California
# Colorado
# Connecticut
# Delaware
# District of Columbia
# Florida
# Georgia
# Hawaii
# Idaho
# Illinois
# Indiana
# Iowa
# Kansas
# Kentucky
# Louisiana
# Maine
# Maryland
# Massachusetts
# Michigan
# Minnesota
# Mississippi
# Missouri
# Montana
# Nebraska
# Nevada
# New Hampshire
# New Jersey
# New Mexico
# New York
# North Carolina
# North Dakota
# Ohio
# Oklahoma
# Oregon
# Pennsylvania
# Rhode Island
# South Carolina
# South Dakota
# Tennessee
# ...

# %% [markdown]
# Issue and justification: There is an issue of consistency involving how locations are named between both data sets. When visually inspecting both sets of records df_gdp uses a (county_name, state) naming convention, whereas df_ue uses a (county_name county, state) naming convention. Additionally even though both sets of records use different naming conventions the both still have 68 matching records. There shouldn't be any matching records when using different naming conventions. Finally some of the locations are only the states name which creates major inconsistency in the data.

# %% [markdown]
# ### Quality Issue 2:

# %%
df_gdp.tail(10)
# Out:
#                                                   GeoFIPS   GeoName Region  \
# 108046                                            "98000"  Far West    8.0
# 108047                                            "98000"  Far West    8.0
# 108048                                            "98000"  Far West    8.0
# 108049                                            "98000"  Far West    8.0
# 108050                                            "98000"  Far West    8.0
# 108051                                            "98000"  Far West    8.0
# 108052              Note: See the included footnote file.       NaN    NaN
# 108053  CAGDP11: Contributions to percent change in re...       NaN    NaN
# 108054  Last updated: December 7, 2023 -- new statisti...       NaN    NaN
# 108055                   U.S. Bureau of Economic Analysis       NaN    NaN
#
#        TableName  LineCode IndustryClassification  \
# 108046   CAGDP11      87.0                  11,21
# ...

# %%
df_ue.tail(10)
# Out:
#       FIPS_Code State                    Area_Name  \
# 3267      72135    PR       Toa Alta Municipio, PR
# 3268      72137    PR       Toa Baja Municipio, PR
# 3269      72139    PR  Trujillo Alto Municipio, PR
# 3270      72141    PR         Utuado Municipio, PR
# 3271      72143    PR      Vega Alta Municipio, PR
# 3272      72145    PR      Vega Baja Municipio, PR
# 3273      72147    PR        Vieques Municipio, PR
# 3274      72149    PR       Villalba Municipio, PR
# 3275      72151    PR        Yabucoa Municipio, PR
# 3276      72153    PR          Yauco Municipio, PR
#
#       Rural_Urban_Continuum_Code_2013  Urban_Influence_Code_2013  Metro_2013  \
# 3267                              1.0                        1.0         1.0
# 3268                              1.0                        1.0         1.0
# 3269                              1.0                        1.0         1.0
# 3270                              2.0                        2.0         1.0
# ...

# %%
# looking at the number of times each value appears in df_gdp
df_gdp['GeoName'].value_counts()
# Out:
# GeoName
# United States *    34
# Gallia, OH         34
# Greene, OH         34
# Guernsey, OH       34
# Hamilton, OH       34
#                    ..
# Hardin, KY         34
# Harlan, KY         34
# Harrison, KY       34
# Hart, KY           34
# Far West           34
# Name: count, Length: 3178, dtype: int64

# %%
# Looking at the number of times each value appears in df_ue
df_ue['Area_Name'].value_counts()
# Out:
# Area_Name
# District of Columbia    2
# United States           1
# Comanche County, OK     1
# Blaine County, OK       1
# Bryan County, OK        1
#                        ..
# Mason County, KY        1
# Meade County, KY        1
# Menifee County, KY      1
# Mercer County, KY       1
# Yauco Municipio, PR     1
# Name: count, Length: 3276, dtype: int64

# %% [markdown]
# Issue and justification: There is an issue of uniqueness in df_gdp. Multiple rows of data are using the same GeoName for identification purposes.

# %% [markdown]
# ### Tidiness Issue 1:

# %%
# Using a single location to inspect the rows of data for that location.
df_gdp.query("GeoName == 'Gallia, OH'")
# Out:
#         GeoFIPS     GeoName Region TableName  LineCode IndustryClassification  \
# 71740   "39053"  Gallia, OH    3.0   CAGDP11       1.0                    ...
# 71741   "39053"  Gallia, OH    3.0   CAGDP11       2.0                    ...
# 71742   "39053"  Gallia, OH    3.0   CAGDP11       3.0                     11
# 71743   "39053"  Gallia, OH    3.0   CAGDP11       6.0                     21
# 71744   "39053"  Gallia, OH    3.0   CAGDP11      10.0                     22
# 71745   "39053"  Gallia, OH    3.0   CAGDP11      11.0                     23
# 71746   "39053"  Gallia, OH    3.0   CAGDP11      12.0                  31-33
# 71747   "39053"  Gallia, OH    3.0   CAGDP11      13.0            321,327-339
# 71748   "39053"  Gallia, OH    3.0   CAGDP11      25.0        311-316,322-326
# 71749   "39053"  Gallia, OH    3.0   CAGDP11      34.0                     42
# 71750   "39053"  Gallia, OH    3.0   CAGDP11      35.0                  44-45
# ...

# %%
# Inspecting the different descriptions of data
df_gdp['Description'].value_counts()
# Out:
# Description
# All industry total (percent change)                                             3178
#    Accommodation and food services                                              3178
#    Administrative and support and waste management and remediation services     3178
#   Educational services, health care, and social assistance                      3178
#    Educational services                                                         3178
#    Health care and social assistance                                            3178
#   Arts, entertainment, recreation, accommodation, and food services             3178
#    Arts, entertainment, and recreation                                          3178
#   Other services (except government and government enterprises)                 3178
#  Private industries                                                             3178
# Government and government enterprises                                           3178
# ...

# %% [markdown]
# Issue and justification: There are 34 different variables types within the df_gdp table when filtering by description.

# %% [markdown]
# ### Tidiness Issue 2:

# %%
df_gdp.query("LineCode == 1").head()
# Out:
#       GeoFIPS          GeoName Region TableName  LineCode  \
# 0     "00000"  United States *          CAGDP11       1.0
# 34    "01000"          Alabama      5   CAGDP11       1.0
# 68    "01001"      Autauga, AL      5   CAGDP11       1.0
# 102   "01003"      Baldwin, AL      5   CAGDP11       1.0
# 136   "01005"      Barbour, AL      5   CAGDP11       1.0
#
#     IndustryClassification                           Description  \
# 0                      ...  All industry total (percent change)
# 34                     ...  All industry total (percent change)
# 68                     ...  All industry total (percent change)
# 102                    ...  All industry total (percent change)
# 136                    ...  All industry total (percent change)
#
#                Unit 2018  2019  2020 2021  2022
# 0    Percent change  3.0   2.5  -2.2  5.8   1.9
# 34   Percent change  1.9   1.9  -1.3  4.4   1.7
# 68   Percent change  1.4  -3.2  -0.5  0.3  11.7
# ...

# %%
# demonstration code looking at redundant data
df_gdp.query("LineCode == 1")['Description'].value_counts()
# Out:
# Description
# All industry total (percent change)     3178
# Name: count, dtype: int64

# %%
#demonstration code looking at an example of redundant data 
df_gdp.query("LineCode == 2")['Description'].value_counts()
# Out:
# Description
#  Private industries     3178
# Name: count, dtype: int64

# %% [markdown]
# Issue and justification: Each variable forms a column. When inspecting the data multiple columns represent the same value set. For example, GeoFips and GeoName are refering to the same thing, which is location. LineCode and Description also refer to the same thing.

# %% [markdown]
# ## 3. Clean data
# Clean the data to solve the 4 issues corresponding to data quality and tidiness found in the assessing step. **Make sure you include justifications for your cleaning decisions.**
#
# After the cleaning for each issue, please use **either** the visually or programatical method to validate the cleaning was succesful.
#
# At this stage, you are also expected to remove variables that are unnecessary for your analysis and combine your datasets. Depending on your datasets, you may choose to perform variable combination and elimination before or after the cleaning stage. Your dataset must have **at least** 4 variables after combining the data.

# %%
# FILL IN - Make copies of the datasets to ensure the raw dataframes 
# are not impacted
df_gdp1 = df_gdp
df_ue1 = df_ue

# %% [markdown]
# ### **Quality Issue 1: Naming Consistency**

# %%
df_gdp1.head()
# Out:
#      GeoFIPS      GeoName Region TableName  LineCode IndustryClassification  \
# 68   "01001"  Autauga, AL      5   CAGDP11       1.0                    ...
# 69   "01001"  Autauga, AL      5   CAGDP11       2.0                    ...
# 70   "01001"  Autauga, AL      5   CAGDP11       3.0                     11
# 71   "01001"  Autauga, AL      5   CAGDP11       6.0                     21
# 72   "01001"  Autauga, AL      5   CAGDP11      10.0                     22
#
#                                          Description               Unit  \
# 68              All industry total (percent change)      Percent change
# 69                               Private industries   Percentage points
# 70       Agriculture, forestry, fishing and hunting   Percentage points
# 71    Mining, quarrying, and oil and gas extraction   Percentage points
# 72                                        Utilities   Percentage points
#
#      2018   2019  2020   2021   2022
# 68    1.4   -3.2  -0.5    0.3   11.7
# ...

# %%
df_gdp1 = df_gdp1[df_gdp1['GeoName'].str.contains(',')==True]
df_ue1 = df_ue1[df_ue1['Area_Name'].str.contains(',')==True]
df_ue1['Area_Name'] = df_ue1['Area_Name'].str.replace('County','')
df_ue1['Area_Name'] = df_ue1['Area_Name'].str.replace(' ,',',')
df_ue1.head()
# Out:
#    FIPS_Code State    Area_Name  Rural_Urban_Continuum_Code_2013  \
# 2       1001    AL  Autauga, AL                              2.0
# 3       1003    AL  Baldwin, AL                              3.0
# 4       1005    AL  Barbour, AL                              6.0
# 5       1007    AL     Bibb, AL                              1.0
# 6       1009    AL   Blount, AL                              1.0
#
#    Urban_Influence_Code_2013  Metro_2013  Civilian_labor_force_2000  \
# 2                        2.0         1.0                    21861.0
# 3                        2.0         1.0                    69979.0
# 4                        6.0         0.0                    11449.0
# 5                        1.0         1.0                     8623.0
# 6                        1.0         1.0                    25266.0
#
#    Employed_2000  Unemployed_2000  Unemployment_rate_2000  ...  \
# 2        20971.0            890.0                     4.1  ...
# ...

# %%
# Inspecting how many matching unique location names there are between both data sets

# Creating lists of unique location names from both data frames.
gdp_ls = df_gdp1['GeoName'].unique()
ue_ls = df_ue1['Area_Name'].unique()

# Comparing both lists for matches.
count = 0
for place in gdp_ls:
    if place in ue_ls:
        count += 1
        print(place)
print('There are',count,'matching unique location names between both data sets.')
# Out:
# Autauga, AL
# Baldwin, AL
# Barbour, AL
# Bibb, AL
# Blount, AL
# Bullock, AL
# Butler, AL
# Calhoun, AL
# Chambers, AL
# Cherokee, AL
# Chilton, AL
# Choctaw, AL
# Clarke, AL
# Clay, AL
# Cleburne, AL
# Coffee, AL
# Colbert, AL
# Conecuh, AL
# Coosa, AL
# Covington, AL
# Crenshaw, AL
# Cullman, AL
# Dale, AL
# Dallas, AL
# DeKalb, AL
# Elmore, AL
# Escambia, AL
# Etowah, AL
# Fayette, AL
# Franklin, AL
# Geneva, AL
# Greene, AL
# Hale, AL
# Henry, AL
# Houston, AL
# Jackson, AL
# Jefferson, AL
# Lamar, AL
# Lauderdale, AL
# Lawrence, AL
# Lee, AL
# Limestone, AL
# Lowndes, AL
# Macon, AL
# Madison, AL
# Marengo, AL
# Marion, AL
# Marshall, AL
# Mobile, AL
# Monroe, AL
# Montgomery, AL
# Morgan, AL
# Perry, AL
# Pickens, AL
# Pike, AL
# Randolph, AL
# Russell, AL
# St. Clair, AL
# Shelby, AL
# Sumter, AL
# Talladega, AL
# Tallapoosa, AL
# Tuscaloosa, AL
# Walker, AL
# Washington, AL
# Wilcox, AL
# Winston, AL
# Aleutians East Borough, AK
# Aleutians West Census Area, AK
# ...

# %% [markdown]
# Justification: both df_gdp1 and df_ue1 have matching data sets now for location data containing only data that can be formatted (county, state).

# %% [markdown]
# ### **Quality Issue 2: Uniqueness of values**

# %%
df_gdp1 = df_gdp1.query('LineCode == 1')

# %%
df_gdp1.head()
# Out:
#       GeoFIPS      GeoName Region TableName  LineCode IndustryClassification  \
# 68    "01001"  Autauga, AL      5   CAGDP11       1.0                    ...
# 102   "01003"  Baldwin, AL      5   CAGDP11       1.0                    ...
# 136   "01005"  Barbour, AL      5   CAGDP11       1.0                    ...
# 170   "01007"     Bibb, AL      5   CAGDP11       1.0                    ...
# 204   "01009"   Blount, AL      5   CAGDP11       1.0                    ...
#
#                               Description            Unit  2018  2019   2020  \
# 68   All industry total (percent change)   Percent change   1.4  -3.2   -0.5
# 102  All industry total (percent change)   Percent change   5.1   5.0   -0.6
# 136  All industry total (percent change)   Percent change   1.6  -1.5   -4.1
# 170  All industry total (percent change)   Percent change  -2.4  11.1    4.2
# 204  All industry total (percent change)   Percent change   5.9  -3.1  -10.6
#
#      2021  2022
# 68    0.3  11.7
# ...

# %% [markdown]
# Justification: We can see that by filtering the data by LineCode we can achieve the same result of only one entry for each location.

# %% [markdown]
# ### **Tidiness Issue 1: FILL IN**

# %%
df_ue1.head()
# Out:
#    FIPS_Code State    Area_Name  Rural_Urban_Continuum_Code_2013  \
# 2       1001    AL  Autauga, AL                              2.0
# 3       1003    AL  Baldwin, AL                              3.0
# 4       1005    AL  Barbour, AL                              6.0
# 5       1007    AL     Bibb, AL                              1.0
# 6       1009    AL   Blount, AL                              1.0
#
#    Urban_Influence_Code_2013  Metro_2013  Civilian_labor_force_2000  \
# 2                        2.0         1.0                    21861.0
# 3                        2.0         1.0                    69979.0
# 4                        6.0         0.0                    11449.0
# 5                        1.0         1.0                     8623.0
# 6                        1.0         1.0                    25266.0
#
#    Employed_2000  Unemployed_2000  Unemployment_rate_2000  ...  \
# 2        20971.0            890.0                     4.1  ...
# ...

# %%
#FILL IN - Validate the cleaning was successful

# %% [markdown]
# Justification: *FILL IN*

# %% [markdown]
# ### **Tidiness Issue 2: FILL IN**

# %%
#FILL IN - Apply the cleaning strategy

# %%
#FILL IN - Validate the cleaning was successful

# %% [markdown]
# Justification: *FILL IN*

# %% [markdown]
# ### **Remove unnecessary variables and combine datasets**
#
# Depending on the datasets, you can also peform the combination before the cleaning steps.

# %%
#FILL IN - Remove unnecessary variables and combine datasets

# %% [markdown]
# ## 4. Update your data store
# Update your local database/data store with the cleaned data, following best practices for storing your cleaned data:
#
# - Must maintain different instances / versions of data (raw and cleaned data)
# - Must name the dataset files informatively
# - Ensure both the raw and cleaned data is saved to your database/data store

# %%
#FILL IN - saving data

# %% [markdown]
# ## 5. Answer the research question
#
# ### **5.1:** Define and answer the research question
# Going back to the problem statement in step 1, use the cleaned data to answer the question you raised. Produce **at least** two visualizations using the cleaned data and explain how they help you answer the question.

# %% [markdown]
# *Research question:* FILL IN from answer to Step 1

# %%
#Visual 1 - FILL IN

# %% [markdown]
# *Answer to research question:* FILL IN

# %%
#Visual 2 - FILL IN

# %% [markdown]
# *Answer to research question:* FILL IN

# %% [markdown]
# ### **5.2:** Reflection
# In 2-4 sentences, if you had more time to complete the project, what actions would you take? For example, which data quality and structural issues would you look into further, and what research questions would you further explore?

# %% [markdown]
# *Answer:* FILL IN
